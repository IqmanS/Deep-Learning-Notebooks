# %% [markdown]
# <a href="https://www.kaggle.com/code/iqmansingh/tensorflow-2-0-basics-notebook?scriptVersionId=134155664" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **TensorFlow 2.0 Notebook**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# # Defining a constant

# %%
tensor = tf.constant([[23,4],[32,51]])
tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[23,  4],
#        [32, 51]], dtype=int32)>

# %%
tensor.shape
# Out:
# TensorShape([2, 2])

# %%
tensor.numpy()
# Out:
# array([[23,  4],
#        [32, 51]], dtype=int32)

# %%
arr = np.array([[20,4],[21,51]])
np_tensor = tf.constant(arr)
np_tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int64, numpy=
# array([[20,  4],
#        [21, 51]])>

# %% [markdown]
# # Variables

# %%
variable = tf.Variable([[1.0,2.0],[3.0,4.0]])
variable
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 2.],
#        [3., 4.]], dtype=float32)>

# %%
variable.shape
# Out:
# TensorShape([2, 2])

# %%
variable.numpy()
# Out:
# array([[1., 2.],
#        [3., 4.]], dtype=float32)

# %%
variable[0,1].assign(8)
variable
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 8.],
#        [3., 4.]], dtype=float32)>

# %% [markdown]
# # Operations with Tensors

# %%
tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[23,  4],
#        [32, 51]], dtype=int32)>

# %%
tensor * 3
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[ 69,  12],
#        [ 96, 153]], dtype=int32)>

# %%
np.square(tensor)
# Out:
# array([[ 529,   16],
#        [1024, 2601]], dtype=int32)

# %%
tensor/2
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float64, numpy=
# array([[11.5,  2. ],
#        [16. , 25.5]])>

# %%
tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[23,  4],
#        [32, 51]], dtype=int32)>

# %%
tensor = tensor/2
tensor
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float64, numpy=
# array([[11.5,  2. ],
#        [16. , 25.5]])>

# %%
np.dot(tensor,tensor) # Dot product between 2 tensors
# Out:
# array([[164.25,  74.  ],
#        [592.  , 682.25]])

# %% [markdown]
# # Strings

# %%
tf_str = tf.constant("Iqman")
tf_str
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'Iqman'>

# %%
tf.strings.length(tf_str)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=5>

# %%
tf.strings.length(tf_str).numpy()
# Out:
# 5

# %%
tf.strings.unicode_decode(tf_str,"UTF8")
# Out:
# <tf.Tensor: shape=(5,), dtype=int32, numpy=array([ 73, 113, 109,  97, 110], dtype=int32)>

# %% [markdown]
# # Array of String

# %%
tf_arr = tf.constant(["Iqman","Singh","Bhatia"])

# %%
for i in tf_arr:
    print(i.numpy(),"; Length is:",tf.strings.length(i).numpy())
# Out:
# b'Iqman' ; Length is: 5
# b'Singh' ; Length is: 5
# b'Bhatia' ; Length is: 6
